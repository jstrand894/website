# %% [raw]
# ---
# title: "Jackson Strand"
# about:
#   id: me
#   template: trestles
#   links:
#     - icon: linkedin
#       text: LinkedIn
#       href: https://linkedin.com/in/jacksonstrand
#     - icon: instagram
#       text: Instagram
#       href: https://www.instagram.com/jstrand894/
#     - icon: github
#       text: GitHub
#       href: https://github.com/jstrand894
#   image: ../img/aboutme/deadhorse.jpeg
#
# sidebar: false
# ---

# %% [markdown]
# :::{#me}
#
# I am currently a Master's graduate student at Montana State University studying entomology. I live in Bozeman, MT with my wife Grace.
#
#
#
# ```{=html}
# <div  style="margin: 30px; text-align: center;">
#   <a class="btn btn-primary" href="cv.qmd" role="button" style="padding: 15px 30px;">View my CV</a>
# </div>
# ```
#
#
#
# <div class = "box">
# ## Education
#
# **BA Biology**, 2013-2017 - *University of Minnesota - Twin Cities*
#
# **MSc Entomology**, 2021-2024 - *Montana State University*
# </div>
# ## Employment
#
#
# ```{=html}
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <title>Resume</title>
# <style>
#     body {
#         font-family: Arial, sans-serif;
#         margin: 0;
#         padding: 0;
#     }
#     .container {
#         display: flex;
#         align-items: center; /* Align items vertically */
#         justify-content: space-between;
#         border: 2px solid #ccc; /* Add border */
#         border-color: #f2f2f2;
#         border-radius: 10px; /* Rounded corners */
#         background-color: #f2f2f2; /* Grey background color */
#         padding: 15px; /* Add padding for spacing */
#         height: 100px; /* Set height to align contents vertically */
#     }
#     .text {
#         flex: 1; /* Take up available space */
#     }
#     .date {
#         margin-left: 0px; /* Add some spacing between text and date */
#     }
#     p, .date {
#         margin: 0; /* Reset margin to remove default spacing */
#     }
# </style>
# </head>
# <body>
#
# <div class="container">
#     <div class="text">
#         <p><strong>Pace analytical - Onsite at 3M</strong> - Regulatory IT Analyst</p>
#         <ul>
#             <li>Provided digital support between 3M employees and the 3M Chemical Data Management System (CDMS).</li>
#     </div>
#     <div class="date">2017 - 2021</div>
# </div>
#
# </body>
# </html>
#
#
# ```
#
#
# <!-- ![Me and Grace at Glacier National Park, 2023](../img/aboutme/iceberg.JPG)   -->
#
#
# ```{css, echo = FALSE}
# .grey-box {
#   background-color: #f2f2f2;
#   padding: 10px;
#   border-radius: 5px;
#   border: 1px solid #ccc;
# }
# ```
#
#
# <div class="grey-box">
# Pace Analytical- Onsite at 3M – Regulatory IT Analyst (Maplewood, MN)
# 2013-2017
# 2017-2021
# • Provided digital support between 3M employees and the 3M Chemical Data Management System (CDMS).
# • Integrated, tested, and supported user and data interface between CDMS and SAP.
# • Generated, designed, and communicated unique, detailed reports of material information using SQL, Microsoft Excel, and SAP.
# </div>
